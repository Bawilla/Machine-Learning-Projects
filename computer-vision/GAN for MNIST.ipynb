# %% [markdown]
# # Simplest pytorch GAN implementation
#
# Without essential code and not to many comments.
#
# For a verbose description of a similar algorithm you can have a look here:
# - https://github.com/christianversloot/machine-learning-articles/blob/main/building-a-simple-vanilla-gan-with-pytorch.md

# %% [markdown]
# ## Initialisation

# %%
import torch
from torch import nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
torch.manual_seed(42)

# Define the hyperparameters
latent_dim = 100
num_epochs = 50
batch_size = 128
lr = 0.0002
beta1 = 0.5
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Definition of neural networks

# %%
# Generator Class for a Basic GAN
class Generator(nn.Module):
    """
    Vanilla GAN Generator
    """
    def __init__(self):
        super().__init__()  # Call the superclass constructor
        # Define the layers of the generator
        self.layers = nn.Sequential(
          # First layer: Upsampling from latent dimension to 128 features
          nn.Linear(latent_dim, 128, bias=False),  # No bias to simplify the network
          nn.BatchNorm1d(128, 0.8),  # Batch normalization to stabilize training
          nn.LeakyReLU(0.25),  # Activation function with negative slope

          # Second layer: Upsampling to 256 features
          nn.Linear(128, 256, bias=False),
          nn.BatchNorm1d(256, 0.8),
          nn.LeakyReLU(0.25),

          # Third layer: Upsampling to 512 features
          nn.Linear(256, 512, bias=False),
          nn.BatchNorm1d(512, 0.8),
          nn.LeakyReLU(0.25),

          # Final layer: Upsampling to match the target data dimension
          nn.Linear(512, 28 * 28, bias=False),  # Output shape for MNIST-like data (784 pixels)
          nn.Tanh()  # Activation function to scale output to [-1, 1] (image generation)
        )

    def forward(self, x):
        """Forward pass through the generator"""
        return self.layers(x)  # Pass the input through all the defined layers


# Discriminator Class for a Basic GAN
class Discriminator(nn.Module):
    """
    Vanilla GAN Discriminator
    """
    def __init__(self):
        super().__init__()  # Call the superclass constructor
        # Define the layers of the discriminator
        self.layers = nn.Sequential(
          # Input layer: Flatten and process 28x28 images (784 pixels)
          nn.Linear(28 * 28, 1024), 
          nn.LeakyReLU(0.25),  # Activation function with negative slope

          # Second layer: Processing to 512 features
          nn.Linear(1024, 512), 
          nn.LeakyReLU(0.25),

          # Third layer: Processing to 256 features
          nn.Linear(512, 256), 
          nn.LeakyReLU(0.25),

          # Final output layer: Probability that the image is real or fake
          nn.Linear(256, 1), 
          nn.Sigmoid()  # Sigmoid activation for probability output (0 to 1)
        )

    def forward(self, x):
        """Forward pass through the discriminator"""
        x = x.view(-1, 28 * 28)  # Flatten the input data
        return self.layers(x)  # Pass through all layers


# Instantiate the Generator and Discriminator, moving them to the specified device (CPU/GPU)
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Define the loss function and optimizers for GAN training
criterion = nn.BCELoss()  # Binary cross-entropy for binary classification (real/fake)
g_optimizer = torch.optim.AdamW(generator.parameters(), lr=lr, betas=(beta1, 0.999))  # Generator optimizer
d_optimizer = torch.optim.AdamW(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))  # Discriminator optimizer

# %% [markdown]
# ## Get MNIST data

# %%
# Define the data transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training of the GAN

# %%
# Train the GAN
# Lists to track the losses during training
g_loss_all = []  # Generator loss history
d_loss_all = []  # Discriminator loss history

# Main training loop for GAN
for epoch in range(num_epochs):
    for i, (real_images, _) in enumerate(train_loader):
        # Move the real images to the specified device
        real_images = real_images.to(device)
        actual_batch_size = real_images.size(0)  # Get the actual batch size
        real_labels = torch.ones(actual_batch_size, 1).to(device)  # Labels for real images (1)
        
        # Train the discriminator on real images
        d_optimizer.zero_grad()  # Zero the gradients
        d_outputs_real = discriminator(real_images)  # Discriminator output for real images
        d_loss_real = criterion(d_outputs_real, real_labels)  # Loss for real images
        d_loss_real.backward()  # Backpropagation
        d_optimizer.step()  # Update discriminator weights
        
        # Train the discriminator on fake images
        z = torch.randn(actual_batch_size, latent_dim).to(device)  # Generate random noise
        fake_images = generator(z)  # Generate fake images from noise
        fake_labels = torch.zeros(actual_batch_size, 1).to(device)  # Labels for fake images (0)
        d_outputs_fake = discriminator(fake_images.detach())  # Discriminator output for fake images
        d_loss_fake = criterion(d_outputs_fake, fake_labels)  # Loss for fake images
        d_loss_fake.backward()  # Backpropagation
        d_optimizer.step()  # Update discriminator weights
        
        # Train the generator to fool the discriminator
        g_optimizer.zero_grad()  # Zero the gradients
        z = torch.randn(actual_batch_size, latent_dim).to(device)  # Generate random noise again
        fake_images = generator(z)  # Create fake images
        d_outputs = discriminator(fake_images)  # Discriminator output for these fake images
        g_loss = criterion(d_outputs, real_labels)  # Generator loss (aim to fool the discriminator)
        g_loss.backward()  # Backpropagation
        g_optimizer.step()  # Update generator weights
        
        # Print the losses for tracking progress
        if (i + 1) % 100 == 0:  # Display every 100 steps
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], "
                  f"Discriminator Loss: {d_loss_real.item() + d_loss_fake.item():.4f}, "
                  f"Generator Loss: {g_loss.item():.4f}")
            # Record the losses for visualization later
            g_loss_all.append(g_loss.item())
            d_loss_all.append(d_loss_real.item() + d_loss_fake.item())
# Out:
# Epoch [1/50], Step [100/469], Discriminator Loss: 0.6747, Generator Loss: 1.3857
# Epoch [1/50], Step [200/469], Discriminator Loss: 0.8209, Generator Loss: 1.6651
# Epoch [1/50], Step [300/469], Discriminator Loss: 0.9535, Generator Loss: 3.5242
# Epoch [1/50], Step [400/469], Discriminator Loss: 1.2224, Generator Loss: 2.8242
# Epoch [2/50], Step [100/469], Discriminator Loss: 0.6156, Generator Loss: 1.9905
# Epoch [2/50], Step [200/469], Discriminator Loss: 1.0134, Generator Loss: 0.8472
# Epoch [2/50], Step [300/469], Discriminator Loss: 1.0199, Generator Loss: 0.7748
# Epoch [2/50], Step [400/469], Discriminator Loss: 0.8260, Generator Loss: 0.8761
# Epoch [3/50], Step [100/469], Discriminator Loss: 0.4716, Generator Loss: 2.2733
# Epoch [3/50], Step [200/469], Discriminator Loss: 0.8063, Generator Loss: 3.8924
# Epoch [3/50], Step [300/469], Discriminator Loss: 0.4589, Generator Loss: 3.0242
# Epoch [3/50], Step [400/469], Discriminator Loss: 0.3937, Generator Loss: 2.2631
# Epoch [4/50], Step [100/469], Discriminator Loss: 1.5598, Generator Loss: 0.1336
# Epoch [4/50], Step [200/469], Discriminator Loss: 0.4539, Generator Loss: 4.1973
# Epoch [4/50], Step [300/469], Discriminator Loss: 0.3499, Generator Loss: 2.3740
# Epoch [4/50], Step [400/469], Discriminator Loss: 0.2681, Generator Loss: 2.2250
# Epoch [5/50], Step [100/469], Discriminator Loss: 0.3560, Generator Loss: 1.7073
# Epoch [5/50], Step [200/469], Discriminator Loss: 0.6108, Generator Loss: 1.2789
# Epoch [5/50], Step [300/469], Discriminator Loss: 0.3105, Generator Loss: 3.3880
# Epoch [5/50], Step [400/469], Discriminator Loss: 0.3521, Generator Loss: 1.7489
# Epoch [6/50], Step [100/469], Discriminator Loss: 0.3864, Generator Loss: 4.1885
# Epoch [6/50], Step [200/469], Discriminator Loss: 0.2346, Generator Loss: 2.8848
# Epoch [6/50], Step [300/469], Discriminator Loss: 0.3080, Generator Loss: 3.1038
# Epoch [6/50], Step [400/469], Discriminator Loss: 0.3046, Generator Loss: 2.6166
# Epoch [7/50], Step [100/469], Discriminator Loss: 0.2843, Generator Loss: 3.7845
# Epoch [7/50], Step [200/469], Discriminator Loss: 0.5927, Generator Loss: 5.6118
# Epoch [7/50], Step [300/469], Discriminator Loss: 0.4000, Generator Loss: 2.0985
# Epoch [7/50], Step [400/469], Discriminator Loss: 0.8646, Generator Loss: 6.3169
# Epoch [8/50], Step [100/469], Discriminator Loss: 0.2672, Generator Loss: 3.4541
# Epoch [8/50], Step [200/469], Discriminator Loss: 0.1871, Generator Loss: 3.0683
# Epoch [8/50], Step [300/469], Discriminator Loss: 0.2044, Generator Loss: 3.3448
# Epoch [8/50], Step [400/469], Discriminator Loss: 0.3834, Generator Loss: 1.2981
# Epoch [9/50], Step [100/469], Discriminator Loss: 0.3512, Generator Loss: 3.6382
# Epoch [9/50], Step [200/469], Discriminator Loss: 0.3162, Generator Loss: 2.5872
# Epoch [9/50], Step [300/469], Discriminator Loss: 0.4843, Generator Loss: 5.5839
# Epoch [9/50], Step [400/469], Discriminator Loss: 0.3989, Generator Loss: 2.4848
# Epoch [10/50], Step [100/469], Discriminator Loss: 0.3606, Generator Loss: 3.1577
# Epoch [10/50], Step [200/469], Discriminator Loss: 0.5137, Generator Loss: 1.9756
# Epoch [10/50], Step [300/469], Discriminator Loss: 0.6262, Generator Loss: 3.2236
# Epoch [10/50], Step [400/469], Discriminator Loss: 0.4374, Generator Loss: 2.2873
# Epoch [11/50], Step [100/469], Discriminator Loss: 0.5541, Generator Loss: 3.8640
# Epoch [11/50], Step [200/469], Discriminator Loss: 0.3717, Generator Loss: 4.4340
# Epoch [11/50], Step [300/469], Discriminator Loss: 0.4134, Generator Loss: 2.4878
# Epoch [11/50], Step [400/469], Discriminator Loss: 0.3630, Generator Loss: 3.8605
# Epoch [12/50], Step [100/469], Discriminator Loss: 0.4703, Generator Loss: 2.0542
# Epoch [12/50], Step [200/469], Discriminator Loss: 0.4986, Generator Loss: 3.4357
# Epoch [12/50], Step [300/469], Discriminator Loss: 0.6729, Generator Loss: 1.4830
# Epoch [12/50], Step [400/469], Discriminator Loss: 0.4914, Generator Loss: 2.9836
# Epoch [13/50], Step [100/469], Discriminator Loss: 0.4070, Generator Loss: 2.2842
# Epoch [13/50], Step [200/469], Discriminator Loss: 0.5542, Generator Loss: 2.0855
# Epoch [13/50], Step [300/469], Discriminator Loss: 0.3938, Generator Loss: 3.1094
# Epoch [13/50], Step [400/469], Discriminator Loss: 0.4663, Generator Loss: 2.5518
# Epoch [14/50], Step [100/469], Discriminator Loss: 0.4416, Generator Loss: 2.4575
# Epoch [14/50], Step [200/469], Discriminator Loss: 0.3495, Generator Loss: 2.4687
# Epoch [14/50], Step [300/469], Discriminator Loss: 0.4862, Generator Loss: 2.1509
# Epoch [14/50], Step [400/469], Discriminator Loss: 0.4241, Generator Loss: 2.5876
# Epoch [15/50], Step [100/469], Discriminator Loss: 0.4642, Generator Loss: 2.5445
# Epoch [15/50], Step [200/469], Discriminator Loss: 0.4786, Generator Loss: 2.1523
# Epoch [15/50], Step [300/469], Discriminator Loss: 0.5368, Generator Loss: 2.3043
# Epoch [15/50], Step [400/469], Discriminator Loss: 0.5393, Generator Loss: 1.8070
# Epoch [16/50], Step [100/469], Discriminator Loss: 0.3899, Generator Loss: 2.4697
# Epoch [16/50], Step [200/469], Discriminator Loss: 0.5615, Generator Loss: 2.0834
# Epoch [16/50], Step [300/469], Discriminator Loss: 0.5955, Generator Loss: 1.4186
# Epoch [16/50], Step [400/469], Discriminator Loss: 0.5123, Generator Loss: 3.0162
# Epoch [17/50], Step [100/469], Discriminator Loss: 0.5905, Generator Loss: 1.3450
# Epoch [17/50], Step [200/469], Discriminator Loss: 0.5318, Generator Loss: 2.3634
# Epoch [17/50], Step [300/469], Discriminator Loss: 0.7233, Generator Loss: 1.7790
# Epoch [17/50], Step [400/469], Discriminator Loss: 0.4720, Generator Loss: 2.4167
# Epoch [18/50], Step [100/469], Discriminator Loss: 0.4524, Generator Loss: 2.8437
# Epoch [18/50], Step [200/469], Discriminator Loss: 0.5370, Generator Loss: 2.4789
# Epoch [18/50], Step [300/469], Discriminator Loss: 0.7453, Generator Loss: 3.1219
# Epoch [18/50], Step [400/469], Discriminator Loss: 0.5306, Generator Loss: 2.2759
# Epoch [19/50], Step [100/469], Discriminator Loss: 0.4334, Generator Loss: 2.2444
# Epoch [19/50], Step [200/469], Discriminator Loss: 0.6252, Generator Loss: 1.9842
# Epoch [19/50], Step [300/469], Discriminator Loss: 0.4534, Generator Loss: 2.7259
# Epoch [19/50], Step [400/469], Discriminator Loss: 0.5807, Generator Loss: 2.7254
# Epoch [20/50], Step [100/469], Discriminator Loss: 0.5347, Generator Loss: 1.8033
# Epoch [20/50], Step [200/469], Discriminator Loss: 0.5295, Generator Loss: 1.9274
# Epoch [20/50], Step [300/469], Discriminator Loss: 0.5183, Generator Loss: 2.3251
# Epoch [20/50], Step [400/469], Discriminator Loss: 0.5463, Generator Loss: 1.8980
# Epoch [21/50], Step [100/469], Discriminator Loss: 0.4773, Generator Loss: 2.4104
# Epoch [21/50], Step [200/469], Discriminator Loss: 0.4786, Generator Loss: 2.1529
# Epoch [21/50], Step [300/469], Discriminator Loss: 0.6428, Generator Loss: 2.2978
# Epoch [21/50], Step [400/469], Discriminator Loss: 0.5818, Generator Loss: 1.6796
# Epoch [22/50], Step [100/469], Discriminator Loss: 0.5776, Generator Loss: 2.1997
# Epoch [22/50], Step [200/469], Discriminator Loss: 0.4931, Generator Loss: 2.2430
# Epoch [22/50], Step [300/469], Discriminator Loss: 0.5451, Generator Loss: 2.4376
# Epoch [22/50], Step [400/469], Discriminator Loss: 0.6689, Generator Loss: 2.2637
# Epoch [23/50], Step [100/469], Discriminator Loss: 0.6233, Generator Loss: 1.9219
# Epoch [23/50], Step [200/469], Discriminator Loss: 0.7459, Generator Loss: 1.5919
# Epoch [23/50], Step [300/469], Discriminator Loss: 0.6020, Generator Loss: 2.1141
# Epoch [23/50], Step [400/469], Discriminator Loss: 0.5715, Generator Loss: 2.0279
# Epoch [24/50], Step [100/469], Discriminator Loss: 0.5901, Generator Loss: 1.6030
# Epoch [24/50], Step [200/469], Discriminator Loss: 0.5285, Generator Loss: 2.0669
# Epoch [24/50], Step [300/469], Discriminator Loss: 0.6555, Generator Loss: 1.3194
# Epoch [24/50], Step [400/469], Discriminator Loss: 0.5419, Generator Loss: 2.2709
# Epoch [25/50], Step [100/469], Discriminator Loss: 0.6640, Generator Loss: 1.4933
# Epoch [25/50], Step [200/469], Discriminator Loss: 0.5370, Generator Loss: 1.8600
# Epoch [25/50], Step [300/469], Discriminator Loss: 0.5832, Generator Loss: 2.2708
# Epoch [25/50], Step [400/469], Discriminator Loss: 0.6521, Generator Loss: 1.6405
# Epoch [26/50], Step [100/469], Discriminator Loss: 0.6163, Generator Loss: 2.0989
# Epoch [26/50], Step [200/469], Discriminator Loss: 0.5769, Generator Loss: 2.1710
# Epoch [26/50], Step [300/469], Discriminator Loss: 0.6918, Generator Loss: 2.1216
# Epoch [26/50], Step [400/469], Discriminator Loss: 0.6306, Generator Loss: 1.7000
# Epoch [27/50], Step [100/469], Discriminator Loss: 0.6227, Generator Loss: 1.5216
# Epoch [27/50], Step [200/469], Discriminator Loss: 0.6115, Generator Loss: 2.1823
# Epoch [27/50], Step [300/469], Discriminator Loss: 0.7414, Generator Loss: 2.1299
# Epoch [27/50], Step [400/469], Discriminator Loss: 0.5900, Generator Loss: 1.9240
# Epoch [28/50], Step [100/469], Discriminator Loss: 0.6191, Generator Loss: 2.0884
# Epoch [28/50], Step [200/469], Discriminator Loss: 0.6160, Generator Loss: 1.6644
# Epoch [28/50], Step [300/469], Discriminator Loss: 0.6484, Generator Loss: 1.8447
# Epoch [28/50], Step [400/469], Discriminator Loss: 0.6242, Generator Loss: 1.7501
# Epoch [29/50], Step [100/469], Discriminator Loss: 0.6151, Generator Loss: 1.7785
# Epoch [29/50], Step [200/469], Discriminator Loss: 0.4565, Generator Loss: 2.2616
# Epoch [29/50], Step [300/469], Discriminator Loss: 0.5324, Generator Loss: 2.0290
# Epoch [29/50], Step [400/469], Discriminator Loss: 0.6842, Generator Loss: 1.7462
# Epoch [30/50], Step [100/469], Discriminator Loss: 0.5885, Generator Loss: 1.5975
# Epoch [30/50], Step [200/469], Discriminator Loss: 0.6487, Generator Loss: 1.7632
# Epoch [30/50], Step [300/469], Discriminator Loss: 0.5794, Generator Loss: 2.2883
# Epoch [30/50], Step [400/469], Discriminator Loss: 0.6664, Generator Loss: 2.5552
# Epoch [31/50], Step [100/469], Discriminator Loss: 0.6636, Generator Loss: 1.5673
# Epoch [31/50], Step [200/469], Discriminator Loss: 0.7532, Generator Loss: 2.1568
# Epoch [31/50], Step [300/469], Discriminator Loss: 0.5054, Generator Loss: 2.3400
# Epoch [31/50], Step [400/469], Discriminator Loss: 0.7394, Generator Loss: 1.4868
# Epoch [32/50], Step [100/469], Discriminator Loss: 0.5472, Generator Loss: 2.4308
# Epoch [32/50], Step [200/469], Discriminator Loss: 0.6661, Generator Loss: 2.3411
# Epoch [32/50], Step [300/469], Discriminator Loss: 0.5516, Generator Loss: 2.1021
# Epoch [32/50], Step [400/469], Discriminator Loss: 0.6334, Generator Loss: 1.9858
# Epoch [33/50], Step [100/469], Discriminator Loss: 0.6091, Generator Loss: 1.9639
# Epoch [33/50], Step [200/469], Discriminator Loss: 0.6901, Generator Loss: 1.9257
# Epoch [33/50], Step [300/469], Discriminator Loss: 0.8390, Generator Loss: 1.5231
# Epoch [33/50], Step [400/469], Discriminator Loss: 0.6238, Generator Loss: 1.6186
# Epoch [34/50], Step [100/469], Discriminator Loss: 0.6006, Generator Loss: 2.0390
# Epoch [34/50], Step [200/469], Discriminator Loss: 0.5997, Generator Loss: 1.8213
# Epoch [34/50], Step [300/469], Discriminator Loss: 0.6710, Generator Loss: 1.8227
# Epoch [34/50], Step [400/469], Discriminator Loss: 0.5524, Generator Loss: 1.8437
# Epoch [35/50], Step [100/469], Discriminator Loss: 0.6380, Generator Loss: 1.7800
# Epoch [35/50], Step [200/469], Discriminator Loss: 0.6335, Generator Loss: 2.0379
# Epoch [35/50], Step [300/469], Discriminator Loss: 0.5989, Generator Loss: 1.6804
# Epoch [35/50], Step [400/469], Discriminator Loss: 0.6778, Generator Loss: 1.7942
# Epoch [36/50], Step [100/469], Discriminator Loss: 0.5740, Generator Loss: 1.7824
# Epoch [36/50], Step [200/469], Discriminator Loss: 0.5158, Generator Loss: 2.0047
# Epoch [36/50], Step [300/469], Discriminator Loss: 0.6457, Generator Loss: 1.8470
# Epoch [36/50], Step [400/469], Discriminator Loss: 0.6226, Generator Loss: 1.9200
# Epoch [37/50], Step [100/469], Discriminator Loss: 0.5679, Generator Loss: 1.6765
# Epoch [37/50], Step [200/469], Discriminator Loss: 0.5860, Generator Loss: 1.8849
# Epoch [37/50], Step [300/469], Discriminator Loss: 0.6436, Generator Loss: 1.9081
# Epoch [37/50], Step [400/469], Discriminator Loss: 0.6409, Generator Loss: 2.2223
# Epoch [38/50], Step [100/469], Discriminator Loss: 0.7689, Generator Loss: 1.5945
# Epoch [38/50], Step [200/469], Discriminator Loss: 0.7134, Generator Loss: 1.8145
# Epoch [38/50], Step [300/469], Discriminator Loss: 0.5952, Generator Loss: 1.7244
# Epoch [38/50], Step [400/469], Discriminator Loss: 0.6192, Generator Loss: 1.9495
# Epoch [39/50], Step [100/469], Discriminator Loss: 0.6059, Generator Loss: 1.6649
# Epoch [39/50], Step [200/469], Discriminator Loss: 0.7022, Generator Loss: 1.8927
# Epoch [39/50], Step [300/469], Discriminator Loss: 0.6358, Generator Loss: 1.6367
# Epoch [39/50], Step [400/469], Discriminator Loss: 0.6366, Generator Loss: 1.6862
# Epoch [40/50], Step [100/469], Discriminator Loss: 0.6230, Generator Loss: 2.5806
# Epoch [40/50], Step [200/469], Discriminator Loss: 0.5811, Generator Loss: 2.2145
# Epoch [40/50], Step [300/469], Discriminator Loss: 0.5413, Generator Loss: 1.8683
# Epoch [40/50], Step [400/469], Discriminator Loss: 0.5358, Generator Loss: 1.8536
# Epoch [41/50], Step [100/469], Discriminator Loss: 0.6854, Generator Loss: 1.7870
# Epoch [41/50], Step [200/469], Discriminator Loss: 0.4960, Generator Loss: 1.8648
# Epoch [41/50], Step [300/469], Discriminator Loss: 0.5906, Generator Loss: 1.8485
# Epoch [41/50], Step [400/469], Discriminator Loss: 0.8625, Generator Loss: 1.8485
# Epoch [42/50], Step [100/469], Discriminator Loss: 0.7651, Generator Loss: 2.2629
# Epoch [42/50], Step [200/469], Discriminator Loss: 0.6802, Generator Loss: 1.8951
# Epoch [42/50], Step [300/469], Discriminator Loss: 0.7125, Generator Loss: 1.9982
# Epoch [42/50], Step [400/469], Discriminator Loss: 0.6700, Generator Loss: 2.1984
# Epoch [43/50], Step [100/469], Discriminator Loss: 0.5679, Generator Loss: 2.0181
# Epoch [43/50], Step [200/469], Discriminator Loss: 0.6114, Generator Loss: 1.4475
# Epoch [43/50], Step [300/469], Discriminator Loss: 0.7034, Generator Loss: 2.0737
# Epoch [43/50], Step [400/469], Discriminator Loss: 0.5569, Generator Loss: 2.1833
# Epoch [44/50], Step [100/469], Discriminator Loss: 0.6043, Generator Loss: 2.0998
# Epoch [44/50], Step [200/469], Discriminator Loss: 0.6598, Generator Loss: 1.6209
# Epoch [44/50], Step [300/469], Discriminator Loss: 0.5131, Generator Loss: 2.3764
# Epoch [44/50], Step [400/469], Discriminator Loss: 0.6608, Generator Loss: 1.9307
# Epoch [45/50], Step [100/469], Discriminator Loss: 0.5734, Generator Loss: 2.3362
# Epoch [45/50], Step [200/469], Discriminator Loss: 0.6381, Generator Loss: 1.3961
# Epoch [45/50], Step [300/469], Discriminator Loss: 0.6553, Generator Loss: 1.9259
# Epoch [45/50], Step [400/469], Discriminator Loss: 0.6064, Generator Loss: 2.2290
# Epoch [46/50], Step [100/469], Discriminator Loss: 0.6856, Generator Loss: 2.1846
# Epoch [46/50], Step [200/469], Discriminator Loss: 0.6395, Generator Loss: 1.7210
# Epoch [46/50], Step [300/469], Discriminator Loss: 0.6021, Generator Loss: 2.3145
# Epoch [46/50], Step [400/469], Discriminator Loss: 0.5423, Generator Loss: 2.3995
# Epoch [47/50], Step [100/469], Discriminator Loss: 0.7650, Generator Loss: 1.5308
# Epoch [47/50], Step [200/469], Discriminator Loss: 0.6789, Generator Loss: 1.4195
# Epoch [47/50], Step [300/469], Discriminator Loss: 0.7000, Generator Loss: 1.3720
# Epoch [47/50], Step [400/469], Discriminator Loss: 0.6581, Generator Loss: 2.1877
# Epoch [48/50], Step [100/469], Discriminator Loss: 0.5701, Generator Loss: 2.1523
# Epoch [48/50], Step [200/469], Discriminator Loss: 0.7304, Generator Loss: 1.6485
# Epoch [48/50], Step [300/469], Discriminator Loss: 0.5599, Generator Loss: 2.2837
# Epoch [48/50], Step [400/469], Discriminator Loss: 0.6825, Generator Loss: 1.5920
# Epoch [49/50], Step [100/469], Discriminator Loss: 0.7253, Generator Loss: 1.9300
# Epoch [49/50], Step [200/469], Discriminator Loss: 0.5797, Generator Loss: 2.4818
# Epoch [49/50], Step [300/469], Discriminator Loss: 0.6757, Generator Loss: 1.6948
# Epoch [49/50], Step [400/469], Discriminator Loss: 0.7394, Generator Loss: 1.1952
# Epoch [50/50], Step [100/469], Discriminator Loss: 0.6641, Generator Loss: 1.8739
# Epoch [50/50], Step [200/469], Discriminator Loss: 0.5970, Generator Loss: 1.9998
# Epoch [50/50], Step [300/469], Discriminator Loss: 0.7542, Generator Loss: 1.8083
# Epoch [50/50], Step [400/469], Discriminator Loss: 0.6310, Generator Loss: 1.8168

# %%
# Plot model performance
xrange = range(len(g_loss_all))
plt.figure(figsize=(8, 8))
plt.plot(xrange, g_loss_all, 'bo', label='Generator loss')
plt.plot(xrange, d_loss_all, 'r-', label='Discriminator loss')
plt.title('Generator and discriminator losses')
plt.xlabel('N batch / %d' % 100)
plt.ylabel('loss')
plt.legend()

# %% [markdown]
# ## Now generate new images

# %%
# Generate a batch of random noise vectors
z = torch.randn(batch_size, latent_dim).to(device)  # Random noise (latent vectors)
images = generator(z).cpu().detach().numpy()  # Generate images, convert to numpy array

# Create a new figure to plot the generated images
plt.figure(figsize=(10, 10))  # Adjust the figure size for larger display
for i in range(16):  # Display the first 16 generated images
    image = images[i]  # Extract the i-th image from the generated batch
    image = np.reshape(image, (28, 28))  # Reshape the flattened image to 28x28 (like MNIST)
    
    # Plot the image in a 4x4 grid (16 subplots)
    plt.subplot(4, 4, i + 1)  # Create a subplot for the current image
    plt.imshow(image, cmap='gray')  # Display the image in grayscale
    plt.axis('off')  # Hide the axis ticks and labels to focus on the image

# Show the plot with all the generated images
plt.show()
